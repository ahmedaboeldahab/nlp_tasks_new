# %%
import nltk
import pandas as pd
data = pd.read_csv("NLP_data.csv")

# %%
data.head(25)
data.columns
# Out:
# Index(['email', 'label', 'Subject', 'content'], dtype='object')

# %%
nltk.word_tokenize(data["content"][2])
# Out:
# ['htmlhead',
#  'newslett',
#  'hreftopa',
#  'header',
#  'tabl',
#  'widthnumb',
#  'tr',
#  'valigntop',
#  'td',
#  'widthnumb',
#  'img',
#  'widthnumb',
#  'altcnet',
#  'shopper',
#  'newslett',
#  'alertsbr',
#  'tabl',
#  'widthnumb',
#  'tr',
#  'td',
#  'img',
#  'widthnumb',
#  'td',
#  'td',
#  'img',
#  'widthnumb',
#  'td',
#  'td',
#  'img',
#  'widthnumb',
#  'td',
#  'tr',
#  'tr',
#  'td',
#  'widthnumb',
#  'img',
#  'widthnumb',
#  'td',
#  'td',
#  'widthnumb',
#  'img',
#  'widthnumb',
#  'td',
#  'td',
#  'widthnumb',
#  'img',
#  'widthnumb',
#  'td',
#  'td',
#  'widthnumb',
#  'img',
#  'widthnumb',
#  'td',
#  'tr',
#  'tr',
#  'td',
#  'img',
#  'widthnumb',
#  'td',
#  'tr',
#  'tabl',
#  'right',
#  'column',
#  'td',
#  'td',
#  'widthnumb',
#  'img',
#  'widthnumb',
#  'label',
#  'gif',
#  'tabl',
#  'widthnumb',
#  'tr',
#  'td',
#  'alignmiddl',
#  'img',
#  'widthnumb',
#  'td',
#  'tr',
#  'tabl',
#  'label',
#  'gif',
#  'insert',
#  'ad',
# ...

# %%
from nltk import SnowballStemmer
s_stem=SnowballStemmer(language='english')
(s_stem.stem(data['content'][2]))
# Out:
# "htmlhead newslett hreftopa header tabl widthnumb tr valigntop td widthnumb img widthnumb altcnet shopper newslett alertsbr tabl widthnumb tr td img widthnumb td td img widthnumb td td img widthnumb td tr tr td widthnumb img widthnumb td td widthnumb img widthnumb td td widthnumb img widthnumb td td widthnumb img widthnumb td tr tr td img widthnumb td tr tabl right column td td widthnumb img widthnumb label gif tabl widthnumb tr td alignmiddl img widthnumb td tr tabl label gif insert ad ifram scrollingno widthnumb insert ad br popular popular vertic brick img altalso cnet widthnumb faceari helvetica live tech help nowap april' tech awardap number million open jobsap newscom top ciosa p zdnet peoplesoft end vertic brick end vertic brick td widthnumb widthnumb tabl widthnumb tr td widthnumb tr tr td widthnumb tr tr td widthnumb tr tabl td td widthnumb tabl widthnumb tr td widthnumb tr tabl td tr tr valigntop td widthnumb widthnumb td widthnumb widthnumb td widthnumb widthnumb td widthn
# ...

# %%
from nltk import PorterStemmer
ps=PorterStemmer()
(ps.stem(data['content'][2]))
# Out:
# "htmlhead newslett hreftopa header tabl widthnumb tr valigntop td widthnumb img widthnumb altcnet shopper newslett alertsbr tabl widthnumb tr td img widthnumb td td img widthnumb td td img widthnumb td tr tr td widthnumb img widthnumb td td widthnumb img widthnumb td td widthnumb img widthnumb td td widthnumb img widthnumb td tr tr td img widthnumb td tr tabl right column td td widthnumb img widthnumb label gif tabl widthnumb tr td alignmiddl img widthnumb td tr tabl label gif insert ad ifram scrollingno widthnumb insert ad br popular popular vertic brick img altalso cnet widthnumb faceari helvetica live tech help nowap april' tech awardap number million open jobsap newscom top ciosa p zdnet peoplesoft end vertic brick end vertic brick td widthnumb widthnumb tabl widthnumb tr td widthnumb tr tr td widthnumb tr tr td widthnumb tr tabl td td widthnumb tabl widthnumb tr td widthnumb tr tabl td tr tr valigntop td widthnumb widthnumb td widthnumb widthnumb td widthnumb widthnumb td widthn
# ...
